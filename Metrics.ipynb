# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/Machine-learning-practice/blob/main/Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y_true = [1, 0, 1, 1, 0]
y_pred = [1, 0, 0, 1, 0]
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[2 0]
#  [1 2]]

# %%
# formula Precision=TP+FP/TP​
from sklearn.metrics import precision_score

precision = precision_score(y_true, y_pred)
print("Precision:", precision)
# Out:
# Precision: 1.0

# %%
#recall=TP+FN/TP​
from sklearn.metrics import recall_score

recall = recall_score(y_true, y_pred)
print("Recall:", recall)
# Out:
# Recall: 0.6666666666666666

# %%
#F1=2×Precision+Recal/lPrecision×Recall​
from sklearn.metrics import f1_score

f1 = f1_score(y_true, y_pred)
print("F1 Score:", f1)
# Out:
# F1 Score: 0.8

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.80         5
#    macro avg       0.83      0.83      0.80         5
# weighted avg       0.87      0.80      0.80         5

# %%
y_true = [3, 5, 2, 7]
y_pred = [2.5, 5, 4, 8]
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_true, y_pred)
print("MSE:", mse)
# Out:
# MSE: 1.3125

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_true, y_pred)
print("MAE:", mae)
# Out:
# MAE: 0.875

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.6440677966101696
