# %% [markdown]
# <a href="https://colab.research.google.com/github/arwahh/Machine-learning-practice/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

X = np.array([1,2,3,4,5]).reshape(-1,1)
y = np.array([0,0,0,1,1])

model = LogisticRegression()
model.fit(X, y)

print("Prediction for 4 hours:", model.predict([[4]]))
# Out:
# Prediction for 4 hours: [1]

# %%
from sklearn.linear_model import LogisticRegression
x= [[1],[2],[3],[4],[5]]
y=[0,0,1,1,1]

model=LogisticRegression()
model.fit(x,y)
hours= float(input("how many hours you studied="))
result= model.predict([[hours]])[0]

if result ==1:
  print(f"based on hours {hours} you are likely to pass")
else:
  print(f"based on hours {hours} you  are likely to fail")
# Out:
# how many hours you studied=3.4
# based on hours 3.4 you are likely to pass

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression


X = np.array([1,2,3,4,5,6]).reshape(-1,1)
y = np.array([0,0,0,1,1,1])


model = LogisticRegression()
model.fit(X, y)


prediction = model.predict([[3.5]])


print("Prediction:", prediction)
# Out:
# Prediction: [1]

# %%
print(model.predict_proba([[4]]))
# Out:
# [[0.3917415 0.6082585]]

# %%
new_data = np.array([2, 4, 6]).reshape(-1, 1)
print("Predictions:", model.predict(new_data))
# Out:
# Predictions: [0 1 1]

# %%
print("Coefficient (w):", model.coef_)
print("Intercept (b):", model.intercept_)
# Out:
# Coefficient (w): [[1.0470438]]
# Intercept (b): [-3.74817743]

# %%
prob = model.predict_proba([[4]])
print("Fail Probability:", prob[0][0])
print("Pass Probability:", prob[0][1])
# Out:
# Fail Probability: 0.391741496582348
# Pass Probability: 0.608258503417652

# %%
probs = model.predict_proba([[3.5]])[:, 1]

if probs >= 0.6:
    print("Class 1")
else:
    print("Class 0")
# Out:
# Class 0
